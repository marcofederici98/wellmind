# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

# %%
df = pd.read_csv('../../data/output/df_tradotto.csv').drop('Unnamed: 0', axis = 1)

# %%
df
# Out:
#      mh_coverage_flag mh_coverage_awareness_flag mh_employer_discussion  \
# 0                  No                         No                     No
# 1                  No                         Sì                     Sì
# 2                  No                         No                     No
# 3                  Sì                         No                     No
# 4                  Sì                         Sì                     No
# ...               ...                        ...                    ...
# 1428               Sì                         No                     No
# 1429               Sì                         No                     No
# 1430               Sì                         Sì                     Sì
# 1431        Non lo so                  Non lo so                     No
# 1432               Sì                         No                     No
#
#      mh_resources_provided mh_anonimity_flag            mh_medical_leave  \
# ...

# %%
import plotly.express as px

# %%
# %%time
fig = px.histogram(df, x = ['mh_disorder_current', 'mh_disorder_past'], color = "age")
fig.show()
# Out:
# <div>                            <div id="9aae0335-d693-42ff-886a-c5b2d7e5f4dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9aae0335-d693-42ff-886a-c5b2d7e5f4dd")) {                    Plotly.newPlot(                        "9aae0335-d693-42ff-886a-c5b2d7e5f4dd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=36-49<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"36-49","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"36-49","offsetgroup":"36-49","orientation":"v","showlegend":true,"x":["No","No","S\u00ec","S\u00ec","S\u00ec","S\u00ec","S\u00ec","No","No","No","No","S\u00ec","S\u00ec","No","S\u00ec","S\u00ec","No","No","S\u00ec","S\u00ec","S\u00ec","S\u00ec","No","No","No","No","No","No"
# ...

# %%
list(df.columns)
# Out:
# ['mh_coverage_flag',
#  'mh_coverage_awareness_flag',
#  'mh_employer_discussion',
#  'mh_resources_provided',
#  'mh_anonimity_flag',
#  'mh_medical_leave',
#  'mh_discussion_neg_impact',
#  'mh_discussion_cowork',
#  'mh_discussion_supervis',
#  'mh_conseq_coworkers',
#  'mh_eq_ph_employer',
#  'prev_mh_benefits',
#  'future_mh_specification',
#  'mh_hurt_on_career',
#  'mh_neg_view_cowork',
#  'mh_sharing_friends/fam_flag',
#  'mh_bad_response_workplace',
#  'mh_family_hist',
#  'mh_disorder_past',
#  'mh_disorder_current',
#  'mh_diagnos_proffesional',
#  'mh_sought_proffes_treatm',
#  'sex',
#  'remote_flag',
#  'age']

# %%
lista = list(df.columns)

# %%
sql=''
sql += '(codice_azienda VARCHAR(255),'
for i in lista:
    sql += str(i)
    sql += ' VARCHAR(255),'
sql += 'PRIMARY KEY (codice_azienda)'
sql += ');'

# %%
sql.replace('/','_')
# Out:
# '(codice_azienda VARCHAR(255),mh_coverage_flag VARCHAR(255),mh_coverage_awareness_flag VARCHAR(255),mh_employer_discussion VARCHAR(255),mh_resources_provided VARCHAR(255),mh_anonimity_flag VARCHAR(255),mh_medical_leave VARCHAR(255),mh_discussion_neg_impact VARCHAR(255),mh_discussion_cowork VARCHAR(255),mh_discussion_supervis VARCHAR(255),mh_conseq_coworkers VARCHAR(255),mh_eq_ph_employer VARCHAR(255),prev_mh_benefits VARCHAR(255),future_mh_specification VARCHAR(255),mh_hurt_on_career VARCHAR(255),mh_neg_view_cowork VARCHAR(255),mh_sharing_friends_fam_flag VARCHAR(255),mh_bad_response_workplace VARCHAR(255),mh_family_hist VARCHAR(255),mh_disorder_past VARCHAR(255),mh_disorder_current VARCHAR(255),mh_diagnos_proffesional VARCHAR(255),mh_sought_proffes_treatm VARCHAR(255),sex VARCHAR(255),remote_flag VARCHAR(255),age VARCHAR(255),PRIMARY KEY (codice_azienda));'

# %%
df
# Out:
#      mh_coverage_flag mh_coverage_awareness_flag mh_employer_discussion  \
# 0                  No                         No                     No
# 1                  No                         Sì                     Sì
# 2                  No                         No                     No
# 3                  Sì                         No                     No
# 4                  Sì                         Sì                     No
# ...               ...                        ...                    ...
# 1428               Sì                         No                     No
# 1429               Sì                         No                     No
# 1430               Sì                         Sì                     Sì
# 1431        Non lo so                  Non lo so                     No
# 1432               Sì                         No                     No
#
#      mh_resources_provided mh_anonimity_flag            mh_medical_leave  \
# ...

# %%
lista_tuple = []

# %%
tuple1 = [10,6,45,89,90,1,225,76]

# %%
tuple2 = (i for i in tuple1 if i%5 == 0)
print(tuple2)
# Out:
# <generator object <genexpr> at 0x000001493CA63190>

# %%
tuple2
# Out:
# <generator object <genexpr> at 0x000001493CA63190>

# %%
tuple(tuple1)
# Out:
# (10, 6, 45, 89, 90, 1, 225, 76)

# %%
lista_tuple = []
for j in range(len(df)):
    tupla = []
    tupla.append('0000')
    for i in df:
        tupla.append(df[i][j])
    tupla = tuple(tupla)
    lista_tuple.append(tupla)
lista_tuple
# Out:
# [('0000',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Non lo so',
#   'Very easy',
#   'No',
#   'Non lo so',
#   'Sì',
#   'No',
#   'Non lo so',
#   'No, nessuno',
#   'Non lo so',
#   'Non lo so',
#   'No',
#   'Somewhat open',
#   'No',
#   'No',
#   'Sì',
#   'No',
#   'Sì',
#   'No',
#   'Uomo',
#   'A volte',
#   '36-49'),
#  ('0000',
#   'No',
#   'Sì',
#   'Sì',
#   'Sì',
#   'Sì',
#   'Somewhat easy',
#   'No',
#   'Non lo so',
#   'Sì',
#   'No',
#   'Sì',
#   'Sì, tutti',
#   'No',
#   'No',
#   'No',
#   'Somewhat open',
#   'No',
#   'Sì',
#   'Sì',
#   'Sì',
#   'Sì',
#   'Sì',
#   'Uomo',
#   'Mai',
#   '25-35'),
#  ('0000',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Non lo so',
#   'Neither easy nor difficult',
#   'Non lo so',
#   'Non lo so',
#   'Non lo so',
#   'No',
#   'Non lo so',
#   'No, nessuno',
#   'Sì',
#   'Non lo so',
#   'Non lo so',
#   'Somewhat open',
#   'Non lo so',
#   'No',
#   'Non lo so',
#   'No',
#   'No',
#   'Sì',
#   'Uomo',
# ...
