# %%
import pandas as pd

# %%
df = pd.read_csv('../data/output/df_tradotto.csv').drop('Unnamed: 0', axis = 1)

# %%
df
# Out:
#      mh_coverage_flag mh_coverage_awareness_flag mh_employer_discussion  \
# 0                  No                         No                     No
# 1                  No                         Sì                     Sì
# 2                  No                         No                     No
# 3                  Sì                         No                     No
# 4                  Sì                         Sì                     No
# ...               ...                        ...                    ...
# 1428               Sì                         No                     No
# 1429               Sì                         No                     No
# 1430               Sì                         Sì                     Sì
# 1431        Non lo so                  Non lo so                     No
# 1432               Sì                         No                     No
#
#      mh_resources_provided mh_anonimity_flag            mh_medical_leave  \
# 0                       No         Non lo so                   Very easy
# 1                       Sì                Sì               Somewhat easy
# 2                       No         Non lo so  Neither easy nor difficult
# 3                       No         Non lo so               Somewhat easy
# 4                       No                No  Neither easy nor difficult
# ...                    ...               ...                         ...
# 1428                    No         Non lo so               Somewhat easy
# 1429                    No         Non lo so               Somewhat easy
# 1430                    Sì         Non lo so          Somewhat difficult
# 1431                    Sì         Non lo so          Somewhat difficult
# 1432                    No         Non lo so              Very difficult
#
#      mh_discussion_neg_impact mh_discussion_cowork mh_discussion_supervis  \
# 0                          No            Non lo so                     Sì
# 1                          No            Non lo so                     Sì
# 2                   Non lo so            Non lo so              Non lo so
# 3                   Non lo so            Non lo so                     Sì
# 4                          Sì            Non lo so                     No
# ...                       ...                  ...                    ...
# 1428                Non lo so            Non lo so                     Sì
# 1429                Non lo so            Non lo so                     Sì
# 1430                Non lo so                   Sì                     Sì
# 1431                Non lo so            Non lo so                     Sì
# 1432                Non lo so            Non lo so              Non lo so
#
#      mh_conseq_coworkers  ... mh_sharing_friends/fam_flag  \
# 0                     No  ...               Somewhat open
# 1                     No  ...               Somewhat open
# 2                     No  ...               Somewhat open
# 3                     No  ...                     Neutral
# 4                     No  ...               Somewhat open
# ...                  ...  ...                         ...
# 1428                  No  ...               Somewhat open
# 1429                  No  ...           Somewhat not open
# 1430                  Sì  ...               Somewhat open
# 1431                  No  ...               Somewhat open
# 1432                  No  ...               Somewhat open
#
#      mh_bad_response_workplace mh_family_hist mh_disorder_past  \
# 0                           No             No               Sì
# 1                           No             Sì               Sì
# 2                    Non lo so             No        Non lo so
# 3                           No             No               Sì
# 4                           Sì             Sì               Sì
# ...                        ...            ...              ...
# 1428                 Non lo so             Sì               No
# 1429                 Non lo so             Sì               No
# 1430                        Sì             Sì               Sì
# 1431                        Sì             Sì        Non lo so
# 1432                 Non lo so      Non lo so               Sì
#
#      mh_disorder_current mh_diagnos_proffesional mh_sought_proffes_treatm  \
# 0                     No                      Sì                       No
# 1                     Sì                      Sì                       Sì
# 2                     No                      No                       Sì
# 3                     Sì                      Sì                       Sì
# 4                     Sì                      Sì                       Sì
# ...                  ...                     ...                      ...
# 1428                  No                      No                       Sì
# 1429                  No                      Sì                       No
# 1430                  Sì                      Sì                       Sì
# 1431                  Sì                      Sì                       No
# 1432                  Sì                      No                       No
#
#              sex remote_flag    age
# 0           Uomo     A volte  36-49
# 1           Uomo         Mai  25-35
# 2           Uomo      Sempre  36-49
# 3           Uomo     A volte  36-49
# 4          Donna     A volte  36-49
# ...          ...         ...    ...
# 1428       Donna     A volte  25-35
# 1429        Uomo     A volte    50+
# 1430        Uomo     A volte    50+
# 1431       Donna     A volte  25-35
# 1432  Non-binary     A volte  25-35
#
# [1433 rows x 25 columns]

# %%
conto = (df[df.columns[0]].value_counts(normalize = True)*100).astype(int)

# %%
conto.values
# Out:
# array([57, 22, 20])

# %%
conto.index
# Out:
# Index(['Sì', 'Non lo so', 'No'], dtype='object')

# %%
"""<form action="/action_page.php">
  <label for="cars">Choose a car:</label>
  <select name="cars" id="cars">
    <option value="volvo">Volvo</option>
    <option value="saab">Saab</option>
    <option value="opel">Opel</option>
    <option value="audi">Audi</option>
  </select>
  <br><br>
  <input type="submit" value="Submit">
</form>"""
# Out:
# '<form action="/action_page.php">\n  <label for="cars">Choose a car:</label>\n  <select name="cars" id="cars">\n    <option value="volvo">Volvo</option>\n    <option value="saab">Saab</option>\n    <option value="opel">Opel</option>\n    <option value="audi">Audi</option>\n  </select>\n  <br><br>\n  <input type="submit" value="Submit">\n</form>'

# %%
diz_col = {'mh_coverage_flag': "Il tuo datore di lavoro offre benefits legati al benessere e alla salute mentale?",
 'mh_coverage_awareness_flag': "Conosci le opzioni di assistenza per la salute mentale forniti dal tuo datore di lavoro?",
 'mh_employer_discussion': "Il tuo datore di lavoro ha mai parlato formalmente di salute mentale (ad esempio, nell'ambito di una campagna di benessere o di altre comunicazioni ufficiali)?",
 'mh_resources_provided': 'Il tuo datore di lavoro offre risorse per saperne di più sui problemi di salute mentale e sulle possibilità di chiedere aiuto?',
 'mh_anonimity_flag': "Il tuo anonimato è protetto se scegli di usufruire delle risorse per la salute mentale o del trattamento per l'abuso di sostanze, fornite dal tuo datore di lavoro?",
 'mh_medical_leave': 'Se un problema di salute mentale ti ha spinto a richiedere un congedo medico dal lavoro, chiedere tale congedo sarebbe:',
 'mh_discussion_neg_impact': 'Pensi che parlare di un disturbo mentale con il tuo datore di lavoro possa avere conseguenze negative?',
 'mh_discussion_cowork': 'Parlresti di un disturbo della salute mentale con i tuoi colleghi?',
 'mh_discussion_supervis': 'Ti sentiresti a tuo agio a parlare di un disturbo della salute mentale con il tuo supervisore?',
 'mh_conseq_coworkers': 'Hai mai sentito parlare o osservato conseguenze negative per i colleghi che hanno parlato apertamente di problemi di salute mentale sul posto di lavoro?',
 'mh_eq_ph_employer': 'Ritieni che il tuo datore di lavoro prenda la salute mentale con la stessa serietà della salute fisica?',
 'prev_mh_benefits': 'I tuoi precedenti datori di lavoro hanno mai fornito benefits per la salute mentale?',
 'future_mh_specification': 'Dichiareresti un problema di salute mentale con un potenziale datore di lavoro in un colloquio?',
 'mh_hurt_on_career': 'Ritieni che essere identificato come una persona con un problema di salute mentale danneggerebbe la tua carriera?',
 'mh_neg_view_cowork': 'Pensi che i membri del team/colleghi ti vedrebbero in modo più negativo se sapessero che soffri di un disturbo di salute mentale?',
 'mh_sharing_friends/fam_flag': 'Quanto saresti aperto nel condividere con amici e familiari che soffri di un disturbo della salute mentale?',
 'mh_bad_response_workplace': 'Hai osservato o sperimentato una risposta negativa o mal gestita a un problema di salute mentale nel tuo posto di lavoro attuale o precedente?',
 'mh_family_hist': 'Ci sono persone nella tua famiglia che hanno sofferto di disturbi legati alla salute mentale?',
 'mh_disorder_past': 'Hai avuto un disturbo della salute mentale in passato?',
 'mh_disorder_current': 'Attualmente soffri di un disturbo della salute mentale?',
 'mh_diagnos_proffesional': 'Ti è stato diagnosticato un disturbo di salute mentale da un medico?',
 'mh_sought_proffes_treatm': 'Hai mai richiesto un trattamento per un problema di salute mentale da un professionista?',
 'sex': 'Qual è il tuo sesso?',
 'remote_flag': 'Lavori da remoto?',
 'age': "Qual è la tua fascia d'età?"}

# %%
lista_domande = []

# %%
for i in df:
    lista_domande.append(diz_col[i])

# %%
code = """<form action="/dashboard">
  <label for="graph">Seleziona una domanda</label>
  <select name="domande" id="domande">"""
for i in df:
    code += f'<option value="{i}">{diz_col[i]}</option>'
code += """ </select>
  <br><br>
  <input type="submit" value="Submit">
</form>"""

# %%
print(code)
# Out:
# <form action="/dashboard">
#   <label for="graph">Seleziona una domanda</label>
#   <select name="domande" id="domande"><option value="mh_coverage_flag">Il tuo datore di lavoro offre benefits legati al benessere e alla salute mentale?</option><option value="mh_coverage_awareness_flag">Conosci le opzioni di assistenza per la salute mentale forniti dal tuo datore di lavoro?</option><option value="mh_employer_discussion">Il tuo datore di lavoro ha mai parlato formalmente di salute mentale (ad esempio, nell'ambito di una campagna di benessere o di altre comunicazioni ufficiali)?</option><option value="mh_resources_provided">Il tuo datore di lavoro offre risorse per saperne di più sui problemi di salute mentale e sulle possibilità di chiedere aiuto?</option><option value="mh_anonimity_flag">Il tuo anonimato è protetto se scegli di usufruire delle risorse per la salute mentale o del trattamento per l'abuso di sostanze, fornite dal tuo datore di lavoro?</option><option value="mh_medical_leave">Se un problema di salute mentale ti ha spinto a richiedere un congedo medico dal lavoro, chiedere tale congedo sarebbe:</option><option value="mh_discussion_neg_impact">Pensi che parlare di un disturbo mentale con il tuo datore di lavoro possa avere conseguenze negative?</option><option value="mh_discussion_cowork">Parlresti di un disturbo della salute mentale con i tuoi colleghi?</option><option value="mh_discussion_supervis">Ti sentiresti a tuo agio a parlare di un disturbo della salute mentale con il tuo supervisore?</option><option value="mh_conseq_coworkers">Hai mai sentito parlare o osservato conseguenze negative per i colleghi che hanno parlato apertamente di problemi di salute mentale sul posto di lavoro?</option><option value="mh_eq_ph_employer">Ritieni che il tuo datore di lavoro prenda la salute mentale con la stessa serietà della salute fisica?</option><option value="prev_mh_benefits">I tuoi precedenti datori di lavoro hanno mai fornito benefits per la salute mentale?</option><option value="future_mh_specification">Dichiareresti un problema di salute mentale con un potenziale datore di lavoro in un colloquio?</option><option value="mh_hurt_on_career">Ritieni che essere identificato come una persona con un problema di salute mentale danneggerebbe la tua carriera?</option><option value="mh_neg_view_cowork">Pensi che i membri del team/colleghi ti vedrebbero in modo più negativo se sapessero che soffri di un disturbo di salute mentale?</option><option value="mh_sharing_friends/fam_flag">Quanto saresti aperto nel condividere con amici e familiari che soffri di un disturbo della salute mentale?</option><option value="mh_bad_response_workplace">Hai osservato o sperimentato una risposta negativa o mal gestita a un problema di salute mentale nel tuo posto di lavoro attuale o precedente?</option><option value="mh_family_hist">Ci sono persone nella tua famiglia che hanno sofferto di disturbi legati alla salute mentale?</option><option value="mh_disorder_past">Hai avuto un disturbo della salute mentale in passato?</option><option value="mh_disorder_current">Attualmente soffri di un disturbo della salute mentale?</option><option value="mh_diagnos_proffesional">Ti è stato diagnosticato un disturbo di salute mentale da un medico?</option><option value="mh_sought_proffes_treatm">Hai mai richiesto un trattamento per un problema di salute mentale da un professionista?</option><option value="sex">Qual è il tuo sesso?</option><option value="remote_flag">Lavori da remoto?</option><option value="age">Qual è la tua fascia d'età?</option> </select>
#   <br><br>
#   <input type="submit" value="Submit">
# </form>
