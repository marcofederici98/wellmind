# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import numpy as np

from sklearn.preprocessing import OneHotEncoder
pd.set_option("display.max_columns", 63)

# %%
df = pd.read_csv("../data/input/mht2016.csv")

# %%
renamed_columns = ['self_empl_flag', 'comp_no_empl', 'tech_comp_flag', 'tech_role_flag', 'mh_coverage_flag',
                  'mh_coverage_awareness_flag', 'mh_employer_discussion', 'mh_resources_provided', 'mh_anonimity_flag',
                  'mh_medical_leave', 'mh_discussion_neg_impact', 'ph_discussion_neg_impact', 'mh_discussion_cowork',
                  'mh_discussion_supervis', 'mh_eq_ph_employer', 'mh_conseq_coworkers', 'mh_coverage_flag2', 'mh_online_res_flag',
                  'mh_diagnosed&reveal_clients_flag', 'mh_diagnosed&reveal_clients_impact', 'mh_diagnosed&reveal_cowork_flag', 'mh_cowork_reveal_neg_impact',
                  'mh_prod_impact', 'mh_prod_impact_perc', 'prev_employers_flag', 'prev_mh_benefits', 'prev_mh_benefits_awareness',
                  'prev_mh_discussion', 'prev_mh_resources', 'prev_mh_anonimity', 'prev_mh_discuss_neg_conseq', 'prev_ph_discuss_neg_conseq',
                  'prev_mh_discussion_cowork', 'prev_mh_discussion_supervisor', 'prev_mh_importance_employer', 'prev_mh_conseq_coworkers',
                  'future_ph_specification', 'why/why_not', 'future_mh_specification', 'why/why_not2', 'mh_hurt_on_career', 'mh_neg_view_cowork',
                  'mh_sharing_friends/fam_flag', 'mh_bad_response_workplace', 'mh_for_others_bad_response_workplace', 'mh_family_hist',
                  'mh_disorder_past', 'mh_disorder_current', 'yes:what_diagnosis?', 'maybe:whats_your_diag', 'mh_diagnos_proffesional',
                  'yes:condition_diagnosed', 'mh_sought_proffes_treatm', 'mh_eff_treat_impact_on_work', 'mh_not_eff_treat_impact_on_work',
                  'age', 'sex', 'country_live', 'live_us_teritory', 'country_work', 'work_us_teritory', 'work_position', 'remote_flag']

# %%
#creo un dizionario per tenere traccia delle domande
diz_colonne = {x:y for x, y in zip(renamed_columns, list(df.columns))}

# %%
df.columns = renamed_columns

# %%
df
# Out:
#       self_empl_flag comp_no_empl  tech_comp_flag  tech_role_flag  \
# 0                  0       26-100             1.0             NaN
# 1                  0         6-25             1.0             NaN
# 2                  0         6-25             1.0             NaN
# 3                  1          NaN             NaN             NaN
# 4                  0         6-25             0.0             1.0
# ...              ...          ...             ...             ...
# 1428               1          NaN             NaN             NaN
# 1429               1          NaN             NaN             NaN
# 1430               0      100-500             1.0             NaN
# 1431               0      100-500             0.0             1.0
# 1432               0      100-500             1.0             NaN
#
#                      mh_coverage_flag mh_coverage_awareness_flag  \
# 0     Not eligible for coverage / N/A                        NaN
# 1                                  No                        Yes
# 2                                  No                        NaN
# 3                                 NaN                        NaN
# 4                                 Yes                        Yes
# ...                               ...                        ...
# 1428                              NaN                        NaN
# 1429                              NaN                        NaN
# 1430                              Yes                        Yes
# 1431                     I don't know              I am not sure
# 1432                              Yes                         No
#
#      mh_employer_discussion mh_resources_provided mh_anonimity_flag  \
# 0                        No                    No      I don't know
# 1                       Yes                   Yes               Yes
# 2                        No                    No      I don't know
# 3                       NaN                   NaN               NaN
# 4                        No                    No                No
# ...                     ...                   ...               ...
# 1428                    NaN                   NaN               NaN
# 1429                    NaN                   NaN               NaN
# 1430                    Yes                   Yes      I don't know
# 1431                     No                   Yes      I don't know
# 1432                     No                    No      I don't know
#
#                 mh_medical_leave mh_discussion_neg_impact  \
# 0                      Very easy                       No
# 1                  Somewhat easy                       No
# 2     Neither easy nor difficult                    Maybe
# 3                            NaN                      NaN
# 4     Neither easy nor difficult                      Yes
# ...                          ...                      ...
# 1428                         NaN                      NaN
# 1429                         NaN                      NaN
# 1430          Somewhat difficult                    Maybe
# 1431          Somewhat difficult                    Maybe
# 1432              Very difficult                    Maybe
#
#      ph_discussion_neg_impact mh_discussion_cowork mh_discussion_supervis  \
# 0                          No                Maybe                    Yes
# 1                          No                Maybe                    Yes
# 2                          No                Maybe                  Maybe
# 3                         NaN                  NaN                    NaN
# 4                       Maybe                Maybe                     No
# ...                       ...                  ...                    ...
# 1428                      NaN                  NaN                    NaN
# 1429                      NaN                  NaN                    NaN
# 1430                    Maybe                  Yes                    Yes
# 1431                       No                Maybe                    Yes
# 1432                       No                Maybe                  Maybe
#
#      mh_eq_ph_employer mh_conseq_coworkers  mh_coverage_flag2  \
# 0         I don't know                  No                NaN
# 1                  Yes                  No                NaN
# 2         I don't know                  No                NaN
# 3                  NaN                 NaN                1.0
# 4                   No                  No                NaN
# ...                ...                 ...                ...
# 1428               NaN                 NaN                1.0
# 1429               NaN                 NaN                1.0
# 1430      I don't know                 Yes                NaN
# 1431                No                  No                NaN
# 1432                No                  No                NaN
#
#        mh_online_res_flag mh_diagnosed&reveal_clients_flag  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3     Yes, I know several        Sometimes, if it comes up
# 4                     NaN                              NaN
# ...                   ...                              ...
# 1428  Yes, I know several             Not applicable to me
# 1429          I know some    No, because it doesn't matter
# 1430                  NaN                              NaN
# 1431                  NaN                              NaN
# 1432                  NaN                              NaN
#
#      mh_diagnosed&reveal_clients_impact mh_diagnosed&reveal_cowork_flag  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                          I'm not sure       Sometimes, if it comes up
# 4                                   NaN                             NaN
# ...                                 ...                             ...
# 1428                                NaN            Not applicable to me
# 1429                                 No   No, because it doesn't matter
# 1430                                NaN                             NaN
# 1431                                NaN                             NaN
# 1432                                NaN                             NaN
#
#      mh_cowork_reveal_neg_impact        mh_prod_impact mh_prod_impact_perc  \
# 0                            NaN                   NaN                 NaN
# 1                            NaN                   NaN                 NaN
# 2                            NaN                   NaN                 NaN
# 3                   I'm not sure                   Yes               1-25%
# 4                            NaN                   NaN                 NaN
# ...                          ...                   ...                 ...
# 1428        Not applicable to me  Not applicable to me                 NaN
# 1429                          No                    No                 NaN
# 1430                         NaN                   NaN                 NaN
# 1431                         NaN                   NaN                 NaN
# 1432                         NaN                   NaN                 NaN
#
#       prev_employers_flag   prev_mh_benefits prev_mh_benefits_awareness  \
# 0                       1       No, none did  N/A (not currently aware)
# 1                       1  Yes, they all did        I was aware of some
# 2                       1       No, none did  N/A (not currently aware)
# 3                       1           Some did  N/A (not currently aware)
# 4                       1       I don't know  N/A (not currently aware)
# ...                   ...                ...                        ...
# 1428                    1  Yes, they all did        I was aware of some
# 1429                    0                NaN                        NaN
# 1430                    1           Some did        I was aware of some
# 1431                    1       No, none did  N/A (not currently aware)
# 1432                    0                NaN                        NaN
#
#      prev_mh_discussion prev_mh_resources prev_mh_anonimity  \
# 0          I don't know          None did      I don't know
# 1              None did          Some did       Yes, always
# 2              None did          Some did      I don't know
# 3              None did          None did      I don't know
# 4              Some did          None did      I don't know
# ...                 ...               ...               ...
# 1428           Some did          Some did      I don't know
# 1429                NaN               NaN               NaN
# 1430           None did          Some did         Sometimes
# 1431           None did          None did      I don't know
# 1432                NaN               NaN               NaN
#
#      prev_mh_discuss_neg_conseq prev_ph_discuss_neg_conseq  \
# 0                  Some of them               None of them
# 1                  None of them               None of them
# 2                  I don't know               Some of them
# 3                  Some of them               Some of them
# 4                  Some of them               Some of them
# ...                         ...                        ...
# 1428               I don't know               None of them
# 1429                        NaN                        NaN
# 1430           Yes, all of them               Some of them
# 1431           Yes, all of them               None of them
# 1432                        NaN                        NaN
#
#                  prev_mh_discussion_cowork  \
# 0            Some of my previous employers
# 1     No, at none of my previous employers
# 2            Some of my previous employers
# 3            Some of my previous employers
# 4     No, at none of my previous employers
# ...                                    ...
# 1428         Some of my previous employers
# 1429                                   NaN
# 1430         Some of my previous employers
# 1431  No, at none of my previous employers
# 1432                                   NaN
#
#              prev_mh_discussion_supervisor prev_mh_importance_employer  \
# 0            Some of my previous employers                I don't know
# 1            Some of my previous employers                    Some did
# 2                             I don't know                I don't know
# 3            Some of my previous employers                I don't know
# 4            Some of my previous employers                    Some did
# ...                                    ...                         ...
# 1428         Some of my previous employers                    Some did
# 1429                                   NaN                         NaN
# 1430         Some of my previous employers                    None did
# 1431  No, at none of my previous employers                    None did
# 1432                                   NaN                         NaN
#
#      prev_mh_conseq_coworkers future_ph_specification  \
# 0                None of them                   Maybe
# 1                None of them                   Maybe
# 2                Some of them                     Yes
# 3                Some of them                     Yes
# 4                Some of them                   Maybe
# ...                       ...                     ...
# 1428             None of them                      No
# 1429                      NaN                   Maybe
# 1430             Some of them                   Maybe
# 1431             None of them                   Maybe
# 1432                      NaN                   Maybe
#
#                                             why/why_not  \
# 0                                                   NaN
# 1     It would depend on the health issue. If there ...
# 2     They would provable need to know, to Judge if ...
# 3     old back injury, doesn't cause me many issues ...
# 4     Depending on the interview stage and whether I...
# ...                                                 ...
# 1428  I believe my health information is my personal...
# 1429                                                 QF
# 1430  Fear that doing so would cause the employer to...
# 1431                          Stigma with some diseases
# 1432                                                NaN
#
#      future_mh_specification  \
# 0                      Maybe
# 1                         No
# 2                        Yes
# 3                      Maybe
# 4                         No
# ...                      ...
# 1428                      No
# 1429                      No
# 1430                      No
# 1431                      No
# 1432                      No
#
#                                            why/why_not2  \
# 0                                                   NaN
# 1     While mental health has become a more prominen...
# 2                                      Stigma, mainly.
# 3     would not if I was not 100% sure that the disc...
# 4                                          I don't know
# ...                                                 ...
# 1428  As previously stated, my health information is...
# 1429                                                  E
# 1430  Fear that the employer would consider addition...
# 1431  Feels like I'm making a mountain out of a mole...
# 1432                                                NaN
#
#                mh_hurt_on_career            mh_neg_view_cowork  \
# 0                          Maybe  No, I don't think they would
# 1     No, I don't think it would  No, I don't think they would
# 2                          Maybe                         Maybe
# 3          Yes, I think it would                         Maybe
# 4          Yes, I think it would                         Maybe
# ...                          ...                           ...
# 1428                       Maybe                         Maybe
# 1429              No, it has not       Yes, I think they would
# 1430                 Yes, it has  No, I don't think they would
# 1431  No, I don't think it would  No, I don't think they would
# 1432       Yes, I think it would  No, I don't think they would
#
#      mh_sharing_friends/fam_flag mh_bad_response_workplace  \
# 0                  Somewhat open                        No
# 1                  Somewhat open                        No
# 2                  Somewhat open            Maybe/Not sure
# 3                        Neutral                        No
# 4                  Somewhat open        Yes, I experienced
# ...                          ...                       ...
# 1428               Somewhat open            Maybe/Not sure
# 1429           Somewhat not open            Maybe/Not sure
# 1430               Somewhat open           Yes, I observed
# 1431               Somewhat open        Yes, I experienced
# 1432               Somewhat open            Maybe/Not sure
#
#      mh_for_others_bad_response_workplace mh_family_hist mh_disorder_past  \
# 0                                     NaN             No              Yes
# 1                                     NaN            Yes              Yes
# 2                                     Yes             No            Maybe
# 3                                     NaN             No              Yes
# 4                                     Yes            Yes              Yes
# ...                                   ...            ...              ...
# 1428                                  NaN            Yes               No
# 1429                                Maybe            Yes               No
# 1430                                  Yes            Yes              Yes
# 1431                                Maybe            Yes            Maybe
# 1432                                   No   I don't know              Yes
#
#      mh_disorder_current                                yes:what_diagnosis?  \
# 0                     No                                                NaN
# 1                    Yes  Anxiety Disorder (Generalized, Social, Phobia,...
# 2                     No                                                NaN
# 3                    Yes  Anxiety Disorder (Generalized, Social, Phobia,...
# 4                    Yes  Anxiety Disorder (Generalized, Social, Phobia,...
# ...                  ...                                                ...
# 1428                  No                                                NaN
# 1429                  No                                                NaN
# 1430               Maybe                                                NaN
# 1431                 Yes  Anxiety Disorder (Generalized, Social, Phobia,...
# 1432                 Yes  Obsessive-Compulsive Disorder|Eating Disorder ...
#
#                                   maybe:whats_your_diag  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1428                                                NaN
# 1429                                                NaN
# 1430  Anxiety Disorder (Generalized, Social, Phobia,...
# 1431                                                NaN
# 1432                                                NaN
#
#      mh_diagnos_proffesional  \
# 0                        Yes
# 1                        Yes
# 2                         No
# 3                        Yes
# 4                        Yes
# ...                      ...
# 1428                      No
# 1429                     Yes
# 1430                     Yes
# 1431                     Yes
# 1432                      No
#
#                                 yes:condition_diagnosed  \
# 0     Anxiety Disorder (Generalized, Social, Phobia,...
# 1     Anxiety Disorder (Generalized, Social, Phobia,...
# 2                                                   NaN
# 3     Anxiety Disorder (Generalized, Social, Phobia,...
# 4     Anxiety Disorder (Generalized, Social, Phobia,...
# ...                                                 ...
# 1428                                                NaN
# 1429  Psychotic Disorder (Schizophrenia, Schizoaffec...
# 1430  Anxiety Disorder (Generalized, Social, Phobia,...
# 1431  Mood Disorder (Depression, Bipolar Disorder, etc)
# 1432                                                NaN
#
#       mh_sought_proffes_treatm mh_eff_treat_impact_on_work  \
# 0                            0        Not applicable to me
# 1                            1                      Rarely
# 2                            1        Not applicable to me
# 3                            1                   Sometimes
# 4                            1                   Sometimes
# ...                        ...                         ...
# 1428                         1        Not applicable to me
# 1429                         0                   Sometimes
# 1430                         1                      Rarely
# 1431                         0                   Sometimes
# 1432                         0        Not applicable to me
#
#      mh_not_eff_treat_impact_on_work  age         sex  \
# 0               Not applicable to me   39        Male
# 1                          Sometimes   29        male
# 2               Not applicable to me   38       Male
# 3                          Sometimes   43        male
# 4                          Sometimes   43      Female
# ...                              ...  ...         ...
# 1428            Not applicable to me   34     Female
# 1429                           Often   56        MALE
# 1430                       Sometimes   52        Male
# 1431                           Often   30      Female
# 1432                           Often   25  non-binary
#
#                   country_live live_us_teritory              country_work  \
# 0               United Kingdom              NaN            United Kingdom
# 1     United States of America         Illinois  United States of America
# 2               United Kingdom              NaN            United Kingdom
# 3               United Kingdom              NaN            United Kingdom
# 4     United States of America         Illinois  United States of America
# ...                        ...              ...                       ...
# 1428  United States of America         New York  United States of America
# 1429  United States of America       California               Afghanistan
# 1430  United States of America          Georgia  United States of America
# 1431  United States of America         Nebraska  United States of America
# 1432                    Canada              NaN                    Canada
#
#      work_us_teritory                                      work_position  \
# 0                 NaN                                 Back-end Developer
# 1            Illinois             Back-end Developer|Front-end Developer
# 2                 NaN                                 Back-end Developer
# 3                 NaN                               Supervisor/Team Lead
# 4            Illinois  Executive Leadership|Supervisor/Team Lead|Dev ...
# ...               ...                                                ...
# 1428         New York                                              Other
# 1429              NaN                                            Support
# 1430          Georgia                                 Back-end Developer
# 1431         Nebraska                                    DevOps/SysAdmin
# 1432              NaN                                              Other
#
#      remote_flag
# 0      Sometimes
# 1          Never
# 2         Always
# 3      Sometimes
# 4      Sometimes
# ...          ...
# 1428   Sometimes
# 1429   Sometimes
# 1430   Sometimes
# 1431   Sometimes
# 1432   Sometimes
#
# [1433 rows x 63 columns]

# %%
df['sex'].replace(to_replace = ['Male', 'male', 'Male ', 'M', 'm',
       'man', 'Cis male', 'Male.', 'male 9:1 female, roughly', 'Male (cis)', 'Man', 'Sex is male',
       'cis male', 'Malr', 'Dude', "I'm a man why didn't you make this a drop down question. You should of asked sex? And I would of answered yes please. Seriously how much text can this take? ",
       'mail', 'M|', 'Male/genderqueer', 'male ',
       'Cis Male', 'Male (trans, FtM)',
       'cisdude', 'cis man', 'MALE'], value = 'Male', inplace = True)

df['sex'].replace(to_replace = ['Female', 'female', 'I identify as female.', 'female ',
       'Female assigned at birth ', 'F', 'Woman', 'fm', 'f', 'Cis female ', 'Transitioned, M2F',
       'Genderfluid (born female)', 'Female or Multi-Gender Femme', 'Female ', 'woman', 'female/woman',
       'Cisgender Female', 'fem', 'Female (props for making this a freeform field, though)',
       ' Female', 'Cis-woman', 'female-bodied; no feelings about gender',
       'AFAB'], value = 'Female', inplace = True)

df['sex'].replace(to_replace = ['Bigender', 'non-binary', 'Other/Transfeminine',
       'Androgynous', 'Other', 'nb masculine',
       'none of your business', 'genderqueer', 'Human', 'Genderfluid',
       'Enby', 'genderqueer woman', 'mtf', 'Queer', 'Agender', 'Fluid',
       'Nonbinary', 'human', 'Unicorn', 'Genderqueer',
       'Genderflux demi-girl', 'Transgender woman'], value = 'Non-binary', inplace = True)

# %%
df['sex'].value_counts()
# Out:
# Male          1060
# Female         343
# Non-binary      27
# Name: sex, dtype: int64

# %% [markdown]
# Ci sono alcuni valori errati nell'età (3, 15, 99, 323), che abbiamo sostituito con la media delle età corrette

# %%
mean_age = df[(df['age'] >= 18) | (df['age'] <= 75)]['age'].mean()
df['age'].replace(to_replace = df[(df['age'] < 18) | (df['age'] > 75)]['age'].tolist(), value = mean_age, inplace = True)

# %%
mean_age
# Out:
# 34.28611304954641

# %% [markdown]
# Valori mancanti

# %%
plt.figure(figsize = (16,4))
sns.heatmap(data = df.isna());

# %%
diz_colonne.values()
# Out:
# dict_values(['Are you self-employed?', 'How many employees does your company or organization have?', 'Is your employer primarily a tech company/organization?', 'Is your primary role within your company related to tech/IT?', 'Does your employer provide mental health benefits as part of healthcare coverage?', 'Do you know the options for mental health care available under your employer-provided coverage?', 'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?', 'Does your employer offer resources to learn more about mental health concerns and options for seeking help?', 'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?', 'If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:', 'Do you think that discussing a mental health disorder with your employer would have negative consequences?', 'Do you think that discussing a physical health issue with your employer would have negative consequences?', 'Would you feel comfortable discussing a mental health disorder with your coworkers?', 'Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?', 'Do you feel that your employer takes mental health as seriously as physical health?', 'Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?', 'Do you have medical coverage (private insurance or state-provided) which includes treatment of \xa0mental health issues?', 'Do you know local or online resources to seek help for a mental health disorder?', 'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?', 'If you have revealed a mental health issue to a client or business contact, do you believe this has impacted you negatively?', 'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?', 'If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?', 'Do you believe your productivity is ever affected by a mental health issue?', 'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?', 'Do you have previous employers?', 'Have your previous employers provided mental health benefits?', 'Were you aware of the options for mental health care provided by your previous employers?', 'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?', 'Did your previous employers provide resources to learn more about mental health issues and how to seek help?', 'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?', 'Do you think that discussing a mental health disorder with previous employers would have negative consequences?', 'Do you think that discussing a physical health issue with previous employers would have negative consequences?', 'Would you have been willing to discuss a mental health issue with your previous co-workers?', 'Would you have been willing to discuss a mental health issue with your direct supervisor(s)?', 'Did you feel that your previous employers took mental health as seriously as physical health?', 'Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?', 'Would you be willing to bring up a physical health issue with a potential employer in an interview?', 'Why or why not?', 'Would you bring up a mental health issue with a potential employer in an interview?', 'Why or why not?.1', 'Do you feel that being identified as a person with a mental health issue would hurt y ...

# %%
"""'What country do you live in?', 'What US state or territory do you live in?', 'What country do you work in?', 'What US state or territory do you work in?'
'Are you self-employed?'
"""
# Out:
# "'What country do you live in?', 'What US state or territory do you live in?', 'What country do you work in?', 'What US state or territory do you work in?'\n'Are you self-employed?'\n"

# %%
list(diz_colonne.keys())[0]
# Out:
# 'self_empl_flag'

# %%
list(diz_colonne.keys())[-6:-2]
# Out:
# ['country_live', 'live_us_teritory', 'country_work', 'work_us_teritory']

# %%
df = df.drop(['country_live', 'live_us_teritory', 'yes:condition_diagnosed',
                'country_work', 'work_us_teritory', 'self_empl_flag'], axis = 1)
df
# Out:
#      comp_no_empl  tech_comp_flag  tech_role_flag  \
# 0          26-100             1.0             NaN
# 1            6-25             1.0             NaN
# 2            6-25             1.0             NaN
# 3             NaN             NaN             NaN
# 4            6-25             0.0             1.0
# ...           ...             ...             ...
# 1428          NaN             NaN             NaN
# 1429          NaN             NaN             NaN
# 1430      100-500             1.0             NaN
# 1431      100-500             0.0             1.0
# 1432      100-500             1.0             NaN
#
#                      mh_coverage_flag mh_coverage_awareness_flag  \
# 0     Not eligible for coverage / N/A                        NaN
# 1                                  No                        Yes
# 2                                  No                        NaN
# 3                                 NaN                        NaN
# 4                                 Yes                        Yes
# ...                               ...                        ...
# 1428                              NaN                        NaN
# 1429                              NaN                        NaN
# 1430                              Yes                        Yes
# 1431                     I don't know              I am not sure
# 1432                              Yes                         No
#
#      mh_employer_discussion mh_resources_provided mh_anonimity_flag  \
# 0                        No                    No      I don't know
# 1                       Yes                   Yes               Yes
# 2                        No                    No      I don't know
# 3                       NaN                   NaN               NaN
# 4                        No                    No                No
# ...                     ...                   ...               ...
# 1428                    NaN                   NaN               NaN
# 1429                    NaN                   NaN               NaN
# 1430                    Yes                   Yes      I don't know
# 1431                     No                   Yes      I don't know
# 1432                     No                    No      I don't know
#
#                 mh_medical_leave mh_discussion_neg_impact  \
# 0                      Very easy                       No
# 1                  Somewhat easy                       No
# 2     Neither easy nor difficult                    Maybe
# 3                            NaN                      NaN
# 4     Neither easy nor difficult                      Yes
# ...                          ...                      ...
# 1428                         NaN                      NaN
# 1429                         NaN                      NaN
# 1430          Somewhat difficult                    Maybe
# 1431          Somewhat difficult                    Maybe
# 1432              Very difficult                    Maybe
#
#      ph_discussion_neg_impact mh_discussion_cowork mh_discussion_supervis  \
# 0                          No                Maybe                    Yes
# 1                          No                Maybe                    Yes
# 2                          No                Maybe                  Maybe
# 3                         NaN                  NaN                    NaN
# 4                       Maybe                Maybe                     No
# ...                       ...                  ...                    ...
# 1428                      NaN                  NaN                    NaN
# 1429                      NaN                  NaN                    NaN
# 1430                    Maybe                  Yes                    Yes
# 1431                       No                Maybe                    Yes
# 1432                       No                Maybe                  Maybe
#
#      mh_eq_ph_employer mh_conseq_coworkers  mh_coverage_flag2  \
# 0         I don't know                  No                NaN
# 1                  Yes                  No                NaN
# 2         I don't know                  No                NaN
# 3                  NaN                 NaN                1.0
# 4                   No                  No                NaN
# ...                ...                 ...                ...
# 1428               NaN                 NaN                1.0
# 1429               NaN                 NaN                1.0
# 1430      I don't know                 Yes                NaN
# 1431                No                  No                NaN
# 1432                No                  No                NaN
#
#        mh_online_res_flag mh_diagnosed&reveal_clients_flag  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3     Yes, I know several        Sometimes, if it comes up
# 4                     NaN                              NaN
# ...                   ...                              ...
# 1428  Yes, I know several             Not applicable to me
# 1429          I know some    No, because it doesn't matter
# 1430                  NaN                              NaN
# 1431                  NaN                              NaN
# 1432                  NaN                              NaN
#
#      mh_diagnosed&reveal_clients_impact mh_diagnosed&reveal_cowork_flag  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                          I'm not sure       Sometimes, if it comes up
# 4                                   NaN                             NaN
# ...                                 ...                             ...
# 1428                                NaN            Not applicable to me
# 1429                                 No   No, because it doesn't matter
# 1430                                NaN                             NaN
# 1431                                NaN                             NaN
# 1432                                NaN                             NaN
#
#      mh_cowork_reveal_neg_impact        mh_prod_impact mh_prod_impact_perc  \
# 0                            NaN                   NaN                 NaN
# 1                            NaN                   NaN                 NaN
# 2                            NaN                   NaN                 NaN
# 3                   I'm not sure                   Yes               1-25%
# 4                            NaN                   NaN                 NaN
# ...                          ...                   ...                 ...
# 1428        Not applicable to me  Not applicable to me                 NaN
# 1429                          No                    No                 NaN
# 1430                         NaN                   NaN                 NaN
# 1431                         NaN                   NaN                 NaN
# 1432                         NaN                   NaN                 NaN
#
#       prev_employers_flag   prev_mh_benefits prev_mh_benefits_awareness  \
# 0                       1       No, none did  N/A (not currently aware)
# 1                       1  Yes, they all did        I was aware of some
# 2                       1       No, none did  N/A (not currently aware)
# 3                       1           Some did  N/A (not currently aware)
# 4                       1       I don't know  N/A (not currently aware)
# ...                   ...                ...                        ...
# 1428                    1  Yes, they all did        I was aware of some
# 1429                    0                NaN                        NaN
# 1430                    1           Some did        I was aware of some
# 1431                    1       No, none did  N/A (not currently aware)
# 1432                    0                NaN                        NaN
#
#      prev_mh_discussion prev_mh_resources prev_mh_anonimity  \
# 0          I don't know          None did      I don't know
# 1              None did          Some did       Yes, always
# 2              None did          Some did      I don't know
# 3              None did          None did      I don't know
# 4              Some did          None did      I don't know
# ...                 ...               ...               ...
# 1428           Some did          Some did      I don't know
# 1429                NaN               NaN               NaN
# 1430           None did          Some did         Sometimes
# 1431           None did          None did      I don't know
# 1432                NaN               NaN               NaN
#
#      prev_mh_discuss_neg_conseq prev_ph_discuss_neg_conseq  \
# 0                  Some of them               None of them
# 1                  None of them               None of them
# 2                  I don't know               Some of them
# 3                  Some of them               Some of them
# 4                  Some of them               Some of them
# ...                         ...                        ...
# 1428               I don't know               None of them
# 1429                        NaN                        NaN
# 1430           Yes, all of them               Some of them
# 1431           Yes, all of them               None of them
# 1432                        NaN                        NaN
#
#                  prev_mh_discussion_cowork  \
# 0            Some of my previous employers
# 1     No, at none of my previous employers
# 2            Some of my previous employers
# 3            Some of my previous employers
# 4     No, at none of my previous employers
# ...                                    ...
# 1428         Some of my previous employers
# 1429                                   NaN
# 1430         Some of my previous employers
# 1431  No, at none of my previous employers
# 1432                                   NaN
#
#              prev_mh_discussion_supervisor prev_mh_importance_employer  \
# 0            Some of my previous employers                I don't know
# 1            Some of my previous employers                    Some did
# 2                             I don't know                I don't know
# 3            Some of my previous employers                I don't know
# 4            Some of my previous employers                    Some did
# ...                                    ...                         ...
# 1428         Some of my previous employers                    Some did
# 1429                                   NaN                         NaN
# 1430         Some of my previous employers                    None did
# 1431  No, at none of my previous employers                    None did
# 1432                                   NaN                         NaN
#
#      prev_mh_conseq_coworkers future_ph_specification  \
# 0                None of them                   Maybe
# 1                None of them                   Maybe
# 2                Some of them                     Yes
# 3                Some of them                     Yes
# 4                Some of them                   Maybe
# ...                       ...                     ...
# 1428             None of them                      No
# 1429                      NaN                   Maybe
# 1430             Some of them                   Maybe
# 1431             None of them                   Maybe
# 1432                      NaN                   Maybe
#
#                                             why/why_not  \
# 0                                                   NaN
# 1     It would depend on the health issue. If there ...
# 2     They would provable need to know, to Judge if ...
# 3     old back injury, doesn't cause me many issues ...
# 4     Depending on the interview stage and whether I...
# ...                                                 ...
# 1428  I believe my health information is my personal...
# 1429                                                 QF
# 1430  Fear that doing so would cause the employer to...
# 1431                          Stigma with some diseases
# 1432                                                NaN
#
#      future_mh_specification  \
# 0                      Maybe
# 1                         No
# 2                        Yes
# 3                      Maybe
# 4                         No
# ...                      ...
# 1428                      No
# 1429                      No
# 1430                      No
# 1431                      No
# 1432                      No
#
#                                            why/why_not2  \
# 0                                                   NaN
# 1     While mental health has become a more prominen...
# 2                                      Stigma, mainly.
# 3     would not if I was not 100% sure that the disc...
# 4                                          I don't know
# ...                                                 ...
# 1428  As previously stated, my health information is...
# 1429                                                  E
# 1430  Fear that the employer would consider addition...
# 1431  Feels like I'm making a mountain out of a mole...
# 1432                                                NaN
#
#                mh_hurt_on_career            mh_neg_view_cowork  \
# 0                          Maybe  No, I don't think they would
# 1     No, I don't think it would  No, I don't think they would
# 2                          Maybe                         Maybe
# 3          Yes, I think it would                         Maybe
# 4          Yes, I think it would                         Maybe
# ...                          ...                           ...
# 1428                       Maybe                         Maybe
# 1429              No, it has not       Yes, I think they would
# 1430                 Yes, it has  No, I don't think they would
# 1431  No, I don't think it would  No, I don't think they would
# 1432       Yes, I think it would  No, I don't think they would
#
#      mh_sharing_friends/fam_flag mh_bad_response_workplace  \
# 0                  Somewhat open                        No
# 1                  Somewhat open                        No
# 2                  Somewhat open            Maybe/Not sure
# 3                        Neutral                        No
# 4                  Somewhat open        Yes, I experienced
# ...                          ...                       ...
# 1428               Somewhat open            Maybe/Not sure
# 1429           Somewhat not open            Maybe/Not sure
# 1430               Somewhat open           Yes, I observed
# 1431               Somewhat open        Yes, I experienced
# 1432               Somewhat open            Maybe/Not sure
#
#      mh_for_others_bad_response_workplace mh_family_hist mh_disorder_past  \
# 0                                     NaN             No              Yes
# 1                                     NaN            Yes              Yes
# 2                                     Yes             No            Maybe
# 3                                     NaN             No              Yes
# 4                                     Yes            Yes              Yes
# ...                                   ...            ...              ...
# 1428                                  NaN            Yes               No
# 1429                                Maybe            Yes               No
# 1430                                  Yes            Yes              Yes
# 1431                                Maybe            Yes            Maybe
# 1432                                   No   I don't know              Yes
#
#      mh_disorder_current                                yes:what_diagnosis?  \
# 0                     No                                                NaN
# 1                    Yes  Anxiety Disorder (Generalized, Social, Phobia,...
# 2                     No                                                NaN
# 3                    Yes  Anxiety Disorder (Generalized, Social, Phobia,...
# 4                    Yes  Anxiety Disorder (Generalized, Social, Phobia,...
# ...                  ...                                                ...
# 1428                  No                                                NaN
# 1429                  No                                                NaN
# 1430               Maybe                                                NaN
# 1431                 Yes  Anxiety Disorder (Generalized, Social, Phobia,...
# 1432                 Yes  Obsessive-Compulsive Disorder|Eating Disorder ...
#
#                                   maybe:whats_your_diag  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1428                                                NaN
# 1429                                                NaN
# 1430  Anxiety Disorder (Generalized, Social, Phobia,...
# 1431                                                NaN
# 1432                                                NaN
#
#      mh_diagnos_proffesional  mh_sought_proffes_treatm  \
# 0                        Yes                         0
# 1                        Yes                         1
# 2                         No                         1
# 3                        Yes                         1
# 4                        Yes                         1
# ...                      ...                       ...
# 1428                      No                         1
# 1429                     Yes                         0
# 1430                     Yes                         1
# 1431                     Yes                         0
# 1432                      No                         0
#
#      mh_eff_treat_impact_on_work mh_not_eff_treat_impact_on_work   age  \
# 0           Not applicable to me            Not applicable to me  39.0
# 1                         Rarely                       Sometimes  29.0
# 2           Not applicable to me            Not applicable to me  38.0
# 3                      Sometimes                       Sometimes  43.0
# 4                      Sometimes                       Sometimes  43.0
# ...                          ...                             ...   ...
# 1428        Not applicable to me            Not applicable to me  34.0
# 1429                   Sometimes                           Often  56.0
# 1430                      Rarely                       Sometimes  52.0
# 1431                   Sometimes                           Often  30.0
# 1432        Not applicable to me                           Often  25.0
#
#              sex                                      work_position  \
# 0           Male                                 Back-end Developer
# 1           Male             Back-end Developer|Front-end Developer
# 2           Male                                 Back-end Developer
# 3           Male                               Supervisor/Team Lead
# 4         Female  Executive Leadership|Supervisor/Team Lead|Dev ...
# ...          ...                                                ...
# 1428      Female                                              Other
# 1429        Male                                            Support
# 1430        Male                                 Back-end Developer
# 1431      Female                                    DevOps/SysAdmin
# 1432  Non-binary                                              Other
#
#      remote_flag
# 0      Sometimes
# 1          Never
# 2         Always
# 3      Sometimes
# 4      Sometimes
# ...          ...
# 1428   Sometimes
# 1429   Sometimes
# 1430   Sometimes
# 1431   Sometimes
# 1432   Sometimes
#
# [1433 rows x 57 columns]

# %%
cols = (df.isna().sum() >= df.shape[0]/2).tolist()
to_drop = df.columns[cols]
df.drop(labels = to_drop, axis = 1, inplace = True)

# Dealing with other missing values
from sklearn.impute import SimpleImputer

# Impute nan with the most frequent value (mode) on every row
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp.fit(df)
imp_data = pd.DataFrame(data = imp.transform(df), columns = df.columns)

# %%
imp_data
# Out:
#      comp_no_empl tech_comp_flag                 mh_coverage_flag  \
# 0          26-100            1.0  Not eligible for coverage / N/A
# 1            6-25            1.0                               No
# 2            6-25            1.0                               No
# 3          26-100            1.0                              Yes
# 4            6-25            0.0                              Yes
# ...           ...            ...                              ...
# 1428       26-100            1.0                              Yes
# 1429       26-100            1.0                              Yes
# 1430      100-500            1.0                              Yes
# 1431      100-500            0.0                     I don't know
# 1432      100-500            1.0                              Yes
#
#      mh_coverage_awareness_flag mh_employer_discussion mh_resources_provided  \
# 0                            No                     No                    No
# 1                           Yes                    Yes                   Yes
# 2                            No                     No                    No
# 3                            No                     No                    No
# 4                           Yes                     No                    No
# ...                         ...                    ...                   ...
# 1428                         No                     No                    No
# 1429                         No                     No                    No
# 1430                        Yes                    Yes                   Yes
# 1431              I am not sure                     No                   Yes
# 1432                         No                     No                    No
#
#      mh_anonimity_flag            mh_medical_leave mh_discussion_neg_impact  \
# 0         I don't know                   Very easy                       No
# 1                  Yes               Somewhat easy                       No
# 2         I don't know  Neither easy nor difficult                    Maybe
# 3         I don't know               Somewhat easy                    Maybe
# 4                   No  Neither easy nor difficult                      Yes
# ...                ...                         ...                      ...
# 1428      I don't know               Somewhat easy                    Maybe
# 1429      I don't know               Somewhat easy                    Maybe
# 1430      I don't know          Somewhat difficult                    Maybe
# 1431      I don't know          Somewhat difficult                    Maybe
# 1432      I don't know              Very difficult                    Maybe
#
#      ph_discussion_neg_impact mh_discussion_cowork mh_discussion_supervis  \
# 0                          No                Maybe                    Yes
# 1                          No                Maybe                    Yes
# 2                          No                Maybe                  Maybe
# 3                          No                Maybe                    Yes
# 4                       Maybe                Maybe                     No
# ...                       ...                  ...                    ...
# 1428                       No                Maybe                    Yes
# 1429                       No                Maybe                    Yes
# 1430                    Maybe                  Yes                    Yes
# 1431                       No                Maybe                    Yes
# 1432                       No                Maybe                  Maybe
#
#      mh_eq_ph_employer mh_conseq_coworkers prev_employers_flag  \
# 0         I don't know                  No                   1
# 1                  Yes                  No                   1
# 2         I don't know                  No                   1
# 3         I don't know                  No                   1
# 4                   No                  No                   1
# ...                ...                 ...                 ...
# 1428      I don't know                  No                   1
# 1429      I don't know                  No                   0
# 1430      I don't know                 Yes                   1
# 1431                No                  No                   1
# 1432                No                  No                   0
#
#        prev_mh_benefits prev_mh_benefits_awareness prev_mh_discussion  \
# 0          No, none did  N/A (not currently aware)       I don't know
# 1     Yes, they all did        I was aware of some           None did
# 2          No, none did  N/A (not currently aware)           None did
# 3              Some did  N/A (not currently aware)           None did
# 4          I don't know  N/A (not currently aware)           Some did
# ...                 ...                        ...                ...
# 1428  Yes, they all did        I was aware of some           Some did
# 1429           Some did  N/A (not currently aware)           None did
# 1430           Some did        I was aware of some           None did
# 1431       No, none did  N/A (not currently aware)           None did
# 1432           Some did  N/A (not currently aware)           None did
#
#      prev_mh_resources prev_mh_anonimity prev_mh_discuss_neg_conseq  \
# 0             None did      I don't know               Some of them
# 1             Some did       Yes, always               None of them
# 2             Some did      I don't know               I don't know
# 3             None did      I don't know               Some of them
# 4             None did      I don't know               Some of them
# ...                ...               ...                        ...
# 1428          Some did      I don't know               I don't know
# 1429          None did      I don't know               Some of them
# 1430          Some did         Sometimes           Yes, all of them
# 1431          None did      I don't know           Yes, all of them
# 1432          None did      I don't know               Some of them
#
#      prev_ph_discuss_neg_conseq             prev_mh_discussion_cowork  \
# 0                  None of them         Some of my previous employers
# 1                  None of them  No, at none of my previous employers
# 2                  Some of them         Some of my previous employers
# 3                  Some of them         Some of my previous employers
# 4                  Some of them  No, at none of my previous employers
# ...                         ...                                   ...
# 1428               None of them         Some of my previous employers
# 1429               Some of them         Some of my previous employers
# 1430               Some of them         Some of my previous employers
# 1431               None of them  No, at none of my previous employers
# 1432               Some of them         Some of my previous employers
#
#              prev_mh_discussion_supervisor prev_mh_importance_employer  \
# 0            Some of my previous employers                I don't know
# 1            Some of my previous employers                    Some did
# 2                             I don't know                I don't know
# 3            Some of my previous employers                I don't know
# 4            Some of my previous employers                    Some did
# ...                                    ...                         ...
# 1428         Some of my previous employers                    Some did
# 1429         Some of my previous employers                    None did
# 1430         Some of my previous employers                    None did
# 1431  No, at none of my previous employers                    None did
# 1432         Some of my previous employers                    None did
#
#      prev_mh_conseq_coworkers future_ph_specification  \
# 0                None of them                   Maybe
# 1                None of them                   Maybe
# 2                Some of them                     Yes
# 3                Some of them                     Yes
# 4                Some of them                   Maybe
# ...                       ...                     ...
# 1428             None of them                      No
# 1429             None of them                   Maybe
# 1430             Some of them                   Maybe
# 1431             None of them                   Maybe
# 1432             None of them                   Maybe
#
#                                             why/why_not  \
# 0                                Fear of discrimination
# 1     It would depend on the health issue. If there ...
# 2     They would provable need to know, to Judge if ...
# 3     old back injury, doesn't cause me many issues ...
# 4     Depending on the interview stage and whether I...
# ...                                                 ...
# 1428  I believe my health information is my personal...
# 1429                                                 QF
# 1430  Fear that doing so would cause the employer to...
# 1431                          Stigma with some diseases
# 1432                             Fear of discrimination
#
#      future_mh_specification  \
# 0                      Maybe
# 1                         No
# 2                        Yes
# 3                      Maybe
# 4                         No
# ...                      ...
# 1428                      No
# 1429                      No
# 1430                      No
# 1431                      No
# 1432                      No
#
#                                            why/why_not2  \
# 0                                                Stigma
# 1     While mental health has become a more prominen...
# 2                                      Stigma, mainly.
# 3     would not if I was not 100% sure that the disc...
# 4                                          I don't know
# ...                                                 ...
# 1428  As previously stated, my health information is...
# 1429                                                  E
# 1430  Fear that the employer would consider addition...
# 1431  Feels like I'm making a mountain out of a mole...
# 1432                                             Stigma
#
#                mh_hurt_on_career            mh_neg_view_cowork  \
# 0                          Maybe  No, I don't think they would
# 1     No, I don't think it would  No, I don't think they would
# 2                          Maybe                         Maybe
# 3          Yes, I think it would                         Maybe
# 4          Yes, I think it would                         Maybe
# ...                          ...                           ...
# 1428                       Maybe                         Maybe
# 1429              No, it has not       Yes, I think they would
# 1430                 Yes, it has  No, I don't think they would
# 1431  No, I don't think it would  No, I don't think they would
# 1432       Yes, I think it would  No, I don't think they would
#
#      mh_sharing_friends/fam_flag mh_bad_response_workplace mh_family_hist  \
# 0                  Somewhat open                        No             No
# 1                  Somewhat open                        No            Yes
# 2                  Somewhat open            Maybe/Not sure             No
# 3                        Neutral                        No             No
# 4                  Somewhat open        Yes, I experienced            Yes
# ...                          ...                       ...            ...
# 1428               Somewhat open            Maybe/Not sure            Yes
# 1429           Somewhat not open            Maybe/Not sure            Yes
# 1430               Somewhat open           Yes, I observed            Yes
# 1431               Somewhat open        Yes, I experienced            Yes
# 1432               Somewhat open            Maybe/Not sure   I don't know
#
#      mh_disorder_past mh_disorder_current mh_diagnos_proffesional  \
# 0                 Yes                  No                     Yes
# 1                 Yes                 Yes                     Yes
# 2               Maybe                  No                      No
# 3                 Yes                 Yes                     Yes
# 4                 Yes                 Yes                     Yes
# ...               ...                 ...                     ...
# 1428               No                  No                      No
# 1429               No                  No                     Yes
# 1430              Yes               Maybe                     Yes
# 1431            Maybe                 Yes                     Yes
# 1432              Yes                 Yes                      No
#
#      mh_sought_proffes_treatm mh_eff_treat_impact_on_work  \
# 0                           0        Not applicable to me
# 1                           1                      Rarely
# 2                           1        Not applicable to me
# 3                           1                   Sometimes
# 4                           1                   Sometimes
# ...                       ...                         ...
# 1428                        1        Not applicable to me
# 1429                        0                   Sometimes
# 1430                        1                      Rarely
# 1431                        0                   Sometimes
# 1432                        0        Not applicable to me
#
#      mh_not_eff_treat_impact_on_work   age         sex  \
# 0               Not applicable to me  39.0        Male
# 1                          Sometimes  29.0        Male
# 2               Not applicable to me  38.0        Male
# 3                          Sometimes  43.0        Male
# 4                          Sometimes  43.0      Female
# ...                              ...   ...         ...
# 1428            Not applicable to me  34.0      Female
# 1429                           Often  56.0        Male
# 1430                       Sometimes  52.0        Male
# 1431                           Often  30.0      Female
# 1432                           Often  25.0  Non-binary
#
#                                           work_position remote_flag
# 0                                    Back-end Developer   Sometimes
# 1                Back-end Developer|Front-end Developer       Never
# 2                                    Back-end Developer      Always
# 3                                  Supervisor/Team Lead   Sometimes
# 4     Executive Leadership|Supervisor/Team Lead|Dev ...   Sometimes
# ...                                                 ...         ...
# 1428                                              Other   Sometimes
# 1429                                            Support   Sometimes
# 1430                                 Back-end Developer   Sometimes
# 1431                                    DevOps/SysAdmin   Sometimes
# 1432                                              Other   Sometimes
#
# [1433 rows x 45 columns]

# %%
imp_data.describe()
# Out:
#        comp_no_empl  tech_comp_flag mh_coverage_flag  \
# count          1433          1433.0             1433
# unique            6             2.0                4
# top          26-100             1.0              Yes
# freq            579          1170.0              818
#
#        mh_coverage_awareness_flag mh_employer_discussion  \
# count                        1433                   1433
# unique                          3                      3
# top                            No                     No
# freq                          774                   1100
#
#        mh_resources_provided mh_anonimity_flag mh_medical_leave  \
# count                   1433              1433             1433
# unique                     3                 3                6
# top                       No      I don't know    Somewhat easy
# freq                     818              1029              568
#
#        mh_discussion_neg_impact ph_discussion_neg_impact mh_discussion_cowork  \
# count                      1433                     1433                 1433
# unique                        3                        3                    3
# top                       Maybe                       No                Maybe
# freq                        774                     1124                  766
#
#        mh_discussion_supervis mh_eq_ph_employer mh_conseq_coworkers  \
# count                    1433              1433                1433
# unique                      3                 3                   2
# top                       Yes      I don't know                  No
# freq                      715               780                1335
#
#         prev_employers_flag prev_mh_benefits prev_mh_benefits_awareness  \
# count                  1433             1433                       1433
# unique                    2                4                          4
# top                       1         Some did  N/A (not currently aware)
# freq                   1264              560                        751
#
#        prev_mh_discussion prev_mh_resources prev_mh_anonimity  \
# count                1433              1433              1433
# unique                  4                 3                 4
# top              None did          None did      I don't know
# freq                 1059              1011              1029
#
#        prev_mh_discuss_neg_conseq prev_ph_discuss_neg_conseq  \
# count                        1433                       1433
# unique                          4                          3
# top                  Some of them               Some of them
# freq                          784                        800
#
#             prev_mh_discussion_cowork  prev_mh_discussion_supervisor  \
# count                            1433                           1433
# unique                              3                              4
# top     Some of my previous employers  Some of my previous employers
# freq                              909                            823
#
#        prev_mh_importance_employer prev_mh_conseq_coworkers  \
# count                         1433                     1433
# unique                           4                        3
# top                       None did             None of them
# freq                           632                      927
#
#        future_ph_specification             why/why_not  \
# count                     1433                    1433
# unique                       3                    1085
# top                      Maybe  Fear of discrimination
# freq                       633                     341
#
#        future_mh_specification why/why_not2 mh_hurt_on_career  \
# count                     1433         1433              1433
# unique                       3         1080                 5
# top                         No       Stigma             Maybe
# freq                       883          321               588
#
#        mh_neg_view_cowork mh_sharing_friends/fam_flag  \
# count                1433                        1433
# unique                  5                           6
# top                 Maybe               Somewhat open
# freq                  591                         640
#
#        mh_bad_response_workplace mh_family_hist mh_disorder_past  \
# count                       1433           1433             1433
# unique                         4              3                3
# top                           No            Yes              Yes
# freq                         656            670              736
#
#        mh_disorder_current mh_diagnos_proffesional  mh_sought_proffes_treatm  \
# count                 1433                    1433                      1433
# unique                   3                       2                         2
# top                    Yes                      No                         1
# freq                   575                     717                       839
#
#        mh_eff_treat_impact_on_work mh_not_eff_treat_impact_on_work     age  \
# count                         1433                            1433  1433.0
# unique                           5                               5    49.0
# top           Not applicable to me                           Often    30.0
# freq                           557                             538    94.0
#
#          sex       work_position remote_flag
# count   1433                1433        1433
# unique     3                 264           3
# top     Male  Back-end Developer   Sometimes
# freq    1063                 263         757

# %%
imp_data['mh_coverage_flag'].unique()
# Out:
# array(['Not eligible for coverage / N/A', 'No', 'Yes', "I don't know"],
#       dtype=object)

# %%
domanda = diz_colonne['mh_coverage_flag']
risposte = imp_data['mh_coverage_flag'].unique()
print(domanda)
print(risposte)
# Out:
# Does your employer provide mental health benefits as part of healthcare coverage?
# ['Not eligible for coverage / N/A' 'No' 'Yes' "I don't know"]

# %%
diz_colonne['mh_disorder_current']
# Out:
# 'Do you currently have a mental health disorder?'

# %%
y = imp_data['mh_disorder_current']

# %%
X = imp_data.drop('mh_disorder_current', axis = 1)

# %%
y
# Out:
# 0          No
# 1         Yes
# 2          No
# 3         Yes
# 4         Yes
#         ...
# 1428       No
# 1429       No
# 1430    Maybe
# 1431      Yes
# 1432      Yes
# Name: mh_disorder_current, Length: 1433, dtype: object

# %%
cat_columns = list(X.select_dtypes(include=['category','object']))
cat_columns
# Out:
# ['comp_no_empl',
#  'tech_comp_flag',
#  'mh_coverage_flag',
#  'mh_coverage_awareness_flag',
#  'mh_employer_discussion',
#  'mh_resources_provided',
#  'mh_anonimity_flag',
#  'mh_medical_leave',
#  'mh_discussion_neg_impact',
#  'ph_discussion_neg_impact',
#  'mh_discussion_cowork',
#  'mh_discussion_supervis',
#  'mh_eq_ph_employer',
#  'mh_conseq_coworkers',
#  'prev_employers_flag',
#  'prev_mh_benefits',
#  'prev_mh_benefits_awareness',
#  'prev_mh_discussion',
#  'prev_mh_resources',
#  'prev_mh_anonimity',
#  'prev_mh_discuss_neg_conseq',
#  'prev_ph_discuss_neg_conseq',
#  'prev_mh_discussion_cowork',
#  'prev_mh_discussion_supervisor',
#  'prev_mh_importance_employer',
#  'prev_mh_conseq_coworkers',
#  'future_ph_specification',
#  'why/why_not',
#  'future_mh_specification',
#  'why/why_not2',
#  'mh_hurt_on_career',
#  'mh_neg_view_cowork',
#  'mh_sharing_friends/fam_flag',
#  'mh_bad_response_workplace',
#  'mh_family_hist',
#  'mh_disorder_past',
#  'mh_diagnos_proffesional',
#  'mh_sought_proffes_treatm',
#  'mh_eff_treat_impact_on_work',
#  'mh_not_eff_treat_impact_on_work',
#  'age',
#  'sex',
#  'work_position',
#  'remote_flag']

# %%
len(cat_columns)
# Out:
# 44

# %%
temp = X.describe().T['unique'] < 10

# %%
cat = []
for i in range(len(temp)):
    if temp[i]:
        cat.append(temp.index[i])
cat
# Out:
# ['comp_no_empl',
#  'tech_comp_flag',
#  'mh_coverage_flag',
#  'mh_coverage_awareness_flag',
#  'mh_employer_discussion',
#  'mh_resources_provided',
#  'mh_anonimity_flag',
#  'mh_medical_leave',
#  'mh_discussion_neg_impact',
#  'ph_discussion_neg_impact',
#  'mh_discussion_cowork',
#  'mh_discussion_supervis',
#  'mh_eq_ph_employer',
#  'mh_conseq_coworkers',
#  'prev_employers_flag',
#  'prev_mh_benefits',
#  'prev_mh_benefits_awareness',
#  'prev_mh_discussion',
#  'prev_mh_resources',
#  'prev_mh_anonimity',
#  'prev_mh_discuss_neg_conseq',
#  'prev_ph_discuss_neg_conseq',
#  'prev_mh_discussion_cowork',
#  'prev_mh_discussion_supervisor',
#  'prev_mh_importance_employer',
#  'prev_mh_conseq_coworkers',
#  'future_ph_specification',
#  'future_mh_specification',
#  'mh_hurt_on_career',
#  'mh_neg_view_cowork',
#  'mh_sharing_friends/fam_flag',
#  'mh_bad_response_workplace',
#  'mh_family_hist',
#  'mh_disorder_past',
#  'mh_diagnos_proffesional',
#  'mh_sought_proffes_treatm',
#  'mh_eff_treat_impact_on_work',
#  'mh_not_eff_treat_impact_on_work',
#  'sex',
#  'remote_flag']

# %%
all_col = cat.copy().append('age')

# %%
X[cat].describe()
# Out:
#        comp_no_empl  tech_comp_flag mh_coverage_flag  \
# count          1433          1433.0             1433
# unique            6             2.0                4
# top          26-100             1.0              Yes
# freq            579          1170.0              818
#
#        mh_coverage_awareness_flag mh_employer_discussion  \
# count                        1433                   1433
# unique                          3                      3
# top                            No                     No
# freq                          774                   1100
#
#        mh_resources_provided mh_anonimity_flag mh_medical_leave  \
# count                   1433              1433             1433
# unique                     3                 3                6
# top                       No      I don't know    Somewhat easy
# freq                     818              1029              568
#
#        mh_discussion_neg_impact ph_discussion_neg_impact mh_discussion_cowork  \
# count                      1433                     1433                 1433
# unique                        3                        3                    3
# top                       Maybe                       No                Maybe
# freq                        774                     1124                  766
#
#        mh_discussion_supervis mh_eq_ph_employer mh_conseq_coworkers  \
# count                    1433              1433                1433
# unique                      3                 3                   2
# top                       Yes      I don't know                  No
# freq                      715               780                1335
#
#         prev_employers_flag prev_mh_benefits prev_mh_benefits_awareness  \
# count                  1433             1433                       1433
# unique                    2                4                          4
# top                       1         Some did  N/A (not currently aware)
# freq                   1264              560                        751
#
#        prev_mh_discussion prev_mh_resources prev_mh_anonimity  \
# count                1433              1433              1433
# unique                  4                 3                 4
# top              None did          None did      I don't know
# freq                 1059              1011              1029
#
#        prev_mh_discuss_neg_conseq prev_ph_discuss_neg_conseq  \
# count                        1433                       1433
# unique                          4                          3
# top                  Some of them               Some of them
# freq                          784                        800
#
#             prev_mh_discussion_cowork  prev_mh_discussion_supervisor  \
# count                            1433                           1433
# unique                              3                              4
# top     Some of my previous employers  Some of my previous employers
# freq                              909                            823
#
#        prev_mh_importance_employer prev_mh_conseq_coworkers  \
# count                         1433                     1433
# unique                           4                        3
# top                       None did             None of them
# freq                           632                      927
#
#        future_ph_specification future_mh_specification mh_hurt_on_career  \
# count                     1433                    1433              1433
# unique                       3                       3                 5
# top                      Maybe                      No             Maybe
# freq                       633                     883               588
#
#        mh_neg_view_cowork mh_sharing_friends/fam_flag  \
# count                1433                        1433
# unique                  5                           6
# top                 Maybe               Somewhat open
# freq                  591                         640
#
#        mh_bad_response_workplace mh_family_hist mh_disorder_past  \
# count                       1433           1433             1433
# unique                         4              3                3
# top                           No            Yes              Yes
# freq                         656            670              736
#
#        mh_diagnos_proffesional  mh_sought_proffes_treatm  \
# count                     1433                      1433
# unique                       2                         2
# top                         No                         1
# freq                       717                       839
#
#        mh_eff_treat_impact_on_work mh_not_eff_treat_impact_on_work   sex  \
# count                         1433                            1433  1433
# unique                           5                               5     3
# top           Not applicable to me                           Often  Male
# freq                           557                             538  1063
#
#        remote_flag
# count         1433
# unique           3
# top      Sometimes
# freq           757

# %%
enc = OneHotEncoder(handle_unknown='ignore')

# %%
enc.fit(X)
# Out:
# OneHotEncoder(handle_unknown='ignore')

# %%
enc.fit_transform(X)
# Out:
# <1433x2619 sparse matrix of type '<class 'numpy.float64'>'
# 	with 63052 stored elements in Compressed Sparse Row format>

# %%
X
# Out:
#      comp_no_empl tech_comp_flag                 mh_coverage_flag  \
# 0          26-100            1.0  Not eligible for coverage / N/A
# 1            6-25            1.0                               No
# 2            6-25            1.0                               No
# 3          26-100            1.0                              Yes
# 4            6-25            0.0                              Yes
# ...           ...            ...                              ...
# 1428       26-100            1.0                              Yes
# 1429       26-100            1.0                              Yes
# 1430      100-500            1.0                              Yes
# 1431      100-500            0.0                     I don't know
# 1432      100-500            1.0                              Yes
#
#      mh_coverage_awareness_flag mh_employer_discussion mh_resources_provided  \
# 0                            No                     No                    No
# 1                           Yes                    Yes                   Yes
# 2                            No                     No                    No
# 3                            No                     No                    No
# 4                           Yes                     No                    No
# ...                         ...                    ...                   ...
# 1428                         No                     No                    No
# 1429                         No                     No                    No
# 1430                        Yes                    Yes                   Yes
# 1431              I am not sure                     No                   Yes
# 1432                         No                     No                    No
#
#      mh_anonimity_flag            mh_medical_leave mh_discussion_neg_impact  \
# 0         I don't know                   Very easy                       No
# 1                  Yes               Somewhat easy                       No
# 2         I don't know  Neither easy nor difficult                    Maybe
# 3         I don't know               Somewhat easy                    Maybe
# 4                   No  Neither easy nor difficult                      Yes
# ...                ...                         ...                      ...
# 1428      I don't know               Somewhat easy                    Maybe
# 1429      I don't know               Somewhat easy                    Maybe
# 1430      I don't know          Somewhat difficult                    Maybe
# 1431      I don't know          Somewhat difficult                    Maybe
# 1432      I don't know              Very difficult                    Maybe
#
#      ph_discussion_neg_impact mh_discussion_cowork mh_discussion_supervis  \
# 0                          No                Maybe                    Yes
# 1                          No                Maybe                    Yes
# 2                          No                Maybe                  Maybe
# 3                          No                Maybe                    Yes
# 4                       Maybe                Maybe                     No
# ...                       ...                  ...                    ...
# 1428                       No                Maybe                    Yes
# 1429                       No                Maybe                    Yes
# 1430                    Maybe                  Yes                    Yes
# 1431                       No                Maybe                    Yes
# 1432                       No                Maybe                  Maybe
#
#      mh_eq_ph_employer mh_conseq_coworkers prev_employers_flag  \
# 0         I don't know                  No                   1
# 1                  Yes                  No                   1
# 2         I don't know                  No                   1
# 3         I don't know                  No                   1
# 4                   No                  No                   1
# ...                ...                 ...                 ...
# 1428      I don't know                  No                   1
# 1429      I don't know                  No                   0
# 1430      I don't know                 Yes                   1
# 1431                No                  No                   1
# 1432                No                  No                   0
#
#        prev_mh_benefits prev_mh_benefits_awareness prev_mh_discussion  \
# 0          No, none did  N/A (not currently aware)       I don't know
# 1     Yes, they all did        I was aware of some           None did
# 2          No, none did  N/A (not currently aware)           None did
# 3              Some did  N/A (not currently aware)           None did
# 4          I don't know  N/A (not currently aware)           Some did
# ...                 ...                        ...                ...
# 1428  Yes, they all did        I was aware of some           Some did
# 1429           Some did  N/A (not currently aware)           None did
# 1430           Some did        I was aware of some           None did
# 1431       No, none did  N/A (not currently aware)           None did
# 1432           Some did  N/A (not currently aware)           None did
#
#      prev_mh_resources prev_mh_anonimity prev_mh_discuss_neg_conseq  \
# 0             None did      I don't know               Some of them
# 1             Some did       Yes, always               None of them
# 2             Some did      I don't know               I don't know
# 3             None did      I don't know               Some of them
# 4             None did      I don't know               Some of them
# ...                ...               ...                        ...
# 1428          Some did      I don't know               I don't know
# 1429          None did      I don't know               Some of them
# 1430          Some did         Sometimes           Yes, all of them
# 1431          None did      I don't know           Yes, all of them
# 1432          None did      I don't know               Some of them
#
#      prev_ph_discuss_neg_conseq             prev_mh_discussion_cowork  \
# 0                  None of them         Some of my previous employers
# 1                  None of them  No, at none of my previous employers
# 2                  Some of them         Some of my previous employers
# 3                  Some of them         Some of my previous employers
# 4                  Some of them  No, at none of my previous employers
# ...                         ...                                   ...
# 1428               None of them         Some of my previous employers
# 1429               Some of them         Some of my previous employers
# 1430               Some of them         Some of my previous employers
# 1431               None of them  No, at none of my previous employers
# 1432               Some of them         Some of my previous employers
#
#              prev_mh_discussion_supervisor prev_mh_importance_employer  \
# 0            Some of my previous employers                I don't know
# 1            Some of my previous employers                    Some did
# 2                             I don't know                I don't know
# 3            Some of my previous employers                I don't know
# 4            Some of my previous employers                    Some did
# ...                                    ...                         ...
# 1428         Some of my previous employers                    Some did
# 1429         Some of my previous employers                    None did
# 1430         Some of my previous employers                    None did
# 1431  No, at none of my previous employers                    None did
# 1432         Some of my previous employers                    None did
#
#      prev_mh_conseq_coworkers future_ph_specification  \
# 0                None of them                   Maybe
# 1                None of them                   Maybe
# 2                Some of them                     Yes
# 3                Some of them                     Yes
# 4                Some of them                   Maybe
# ...                       ...                     ...
# 1428             None of them                      No
# 1429             None of them                   Maybe
# 1430             Some of them                   Maybe
# 1431             None of them                   Maybe
# 1432             None of them                   Maybe
#
#                                             why/why_not  \
# 0                                Fear of discrimination
# 1     It would depend on the health issue. If there ...
# 2     They would provable need to know, to Judge if ...
# 3     old back injury, doesn't cause me many issues ...
# 4     Depending on the interview stage and whether I...
# ...                                                 ...
# 1428  I believe my health information is my personal...
# 1429                                                 QF
# 1430  Fear that doing so would cause the employer to...
# 1431                          Stigma with some diseases
# 1432                             Fear of discrimination
#
#      future_mh_specification  \
# 0                      Maybe
# 1                         No
# 2                        Yes
# 3                      Maybe
# 4                         No
# ...                      ...
# 1428                      No
# 1429                      No
# 1430                      No
# 1431                      No
# 1432                      No
#
#                                            why/why_not2  \
# 0                                                Stigma
# 1     While mental health has become a more prominen...
# 2                                      Stigma, mainly.
# 3     would not if I was not 100% sure that the disc...
# 4                                          I don't know
# ...                                                 ...
# 1428  As previously stated, my health information is...
# 1429                                                  E
# 1430  Fear that the employer would consider addition...
# 1431  Feels like I'm making a mountain out of a mole...
# 1432                                             Stigma
#
#                mh_hurt_on_career            mh_neg_view_cowork  \
# 0                          Maybe  No, I don't think they would
# 1     No, I don't think it would  No, I don't think they would
# 2                          Maybe                         Maybe
# 3          Yes, I think it would                         Maybe
# 4          Yes, I think it would                         Maybe
# ...                          ...                           ...
# 1428                       Maybe                         Maybe
# 1429              No, it has not       Yes, I think they would
# 1430                 Yes, it has  No, I don't think they would
# 1431  No, I don't think it would  No, I don't think they would
# 1432       Yes, I think it would  No, I don't think they would
#
#      mh_sharing_friends/fam_flag mh_bad_response_workplace mh_family_hist  \
# 0                  Somewhat open                        No             No
# 1                  Somewhat open                        No            Yes
# 2                  Somewhat open            Maybe/Not sure             No
# 3                        Neutral                        No             No
# 4                  Somewhat open        Yes, I experienced            Yes
# ...                          ...                       ...            ...
# 1428               Somewhat open            Maybe/Not sure            Yes
# 1429           Somewhat not open            Maybe/Not sure            Yes
# 1430               Somewhat open           Yes, I observed            Yes
# 1431               Somewhat open        Yes, I experienced            Yes
# 1432               Somewhat open            Maybe/Not sure   I don't know
#
#      mh_disorder_past mh_diagnos_proffesional mh_sought_proffes_treatm  \
# 0                 Yes                     Yes                        0
# 1                 Yes                     Yes                        1
# 2               Maybe                      No                        1
# 3                 Yes                     Yes                        1
# 4                 Yes                     Yes                        1
# ...               ...                     ...                      ...
# 1428               No                      No                        1
# 1429               No                     Yes                        0
# 1430              Yes                     Yes                        1
# 1431            Maybe                     Yes                        0
# 1432              Yes                      No                        0
#
#      mh_eff_treat_impact_on_work mh_not_eff_treat_impact_on_work   age  \
# 0           Not applicable to me            Not applicable to me  39.0
# 1                         Rarely                       Sometimes  29.0
# 2           Not applicable to me            Not applicable to me  38.0
# 3                      Sometimes                       Sometimes  43.0
# 4                      Sometimes                       Sometimes  43.0
# ...                          ...                             ...   ...
# 1428        Not applicable to me            Not applicable to me  34.0
# 1429                   Sometimes                           Often  56.0
# 1430                      Rarely                       Sometimes  52.0
# 1431                   Sometimes                           Often  30.0
# 1432        Not applicable to me                           Often  25.0
#
#              sex                                      work_position  \
# 0           Male                                 Back-end Developer
# 1           Male             Back-end Developer|Front-end Developer
# 2           Male                                 Back-end Developer
# 3           Male                               Supervisor/Team Lead
# 4         Female  Executive Leadership|Supervisor/Team Lead|Dev ...
# ...          ...                                                ...
# 1428      Female                                              Other
# 1429        Male                                            Support
# 1430        Male                                 Back-end Developer
# 1431      Female                                    DevOps/SysAdmin
# 1432  Non-binary                                              Other
#
#      remote_flag
# 0      Sometimes
# 1          Never
# 2         Always
# 3      Sometimes
# 4      Sometimes
# ...          ...
# 1428   Sometimes
# 1429   Sometimes
# 1430   Sometimes
# 1431   Sometimes
# 1432   Sometimes
#
# [1433 rows x 44 columns]

# %%
df = X.copy()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# supponiamo che il tuo dataframe si chiami "df"
# e che le colonne categoriche abbiano l'etichetta "object" nel dataframe
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()

# definisci la trasformazione da applicare alle colonne categoriche
transformer = ColumnTransformer(
    transformers=[('cat', OneHotEncoder(handle_unknown='ignore'), categorical_columns)],
    remainder='passthrough'
)

# applica la trasformazione al dataframe
df_encoded = transformer.fit_transform(df)
df_encoded
# Out:
# <1433x2619 sparse matrix of type '<class 'numpy.float64'>'
# 	with 63052 stored elements in Compressed Sparse Row format>

# %%
pd.DataFrame(df_encoded)
# Out:
#                                                       0
# 0       (0, 2)\t1.0\n  (0, 7)\t1.0\n  (0, 10)\t1.0\n...
# 1       (0, 4)\t1.0\n  (0, 7)\t1.0\n  (0, 9)\t1.0\n ...
# 2       (0, 4)\t1.0\n  (0, 7)\t1.0\n  (0, 9)\t1.0\n ...
# 3       (0, 2)\t1.0\n  (0, 7)\t1.0\n  (0, 11)\t1.0\n...
# 4       (0, 4)\t1.0\n  (0, 6)\t1.0\n  (0, 11)\t1.0\n...
# ...                                                 ...
# 1428    (0, 2)\t1.0\n  (0, 7)\t1.0\n  (0, 11)\t1.0\n...
# 1429    (0, 2)\t1.0\n  (0, 7)\t1.0\n  (0, 11)\t1.0\n...
# 1430    (0, 1)\t1.0\n  (0, 7)\t1.0\n  (0, 11)\t1.0\n...
# 1431    (0, 1)\t1.0\n  (0, 6)\t1.0\n  (0, 8)\t1.0\n ...
# 1432    (0, 1)\t1.0\n  (0, 7)\t1.0\n  (0, 11)\t1.0\n...
#
# [1433 rows x 1 columns]

# %%
l = ['mh_not_eff_treat_impact_on_work',
'mh_diagnos_proffesional',
'mh_eff_treat_impact_on_work',
'mh_sought_proffes_treatm',
'mh_disorder_past',
'mh_family_hist',
'mh_sharing_friends/fam_flag',
'mh_bad_response_workplace',
'mh_coverage_flag',
'mh_discussion_cowork',

'mh_disorder_past',
'mh_not_eff_treat_impact_on_work',
'mh_eff_treat_impact_on_work',
'mh_sought_proffes_treatm',
'mh_sharing_friends/fam_flag',
'mh_family_hist',
'mh_bad_response_workplace',
'mh_discussion_cowork',
'mh_coverage_flag']

# %%
l = list(set(l))

# %%
len(l)
# Out:
# 10

# %%
l.append('sex')

# %%
l.append('age')

# %%
df[l]
# Out:
#      mh_family_hist mh_disorder_past mh_diagnos_proffesional  \
# 0                No              Yes                     Yes
# 1               Yes              Yes                     Yes
# 2                No            Maybe                      No
# 3                No              Yes                     Yes
# 4               Yes              Yes                     Yes
# ...             ...              ...                     ...
# 1428            Yes               No                      No
# 1429            Yes               No                     Yes
# 1430            Yes              Yes                     Yes
# 1431            Yes            Maybe                     Yes
# 1432   I don't know              Yes                      No
#
#      mh_sought_proffes_treatm mh_not_eff_treat_impact_on_work  \
# 0                           0            Not applicable to me
# 1                           1                       Sometimes
# 2                           1            Not applicable to me
# 3                           1                       Sometimes
# 4                           1                       Sometimes
# ...                       ...                             ...
# 1428                        1            Not applicable to me
# 1429                        0                           Often
# 1430                        1                       Sometimes
# 1431                        0                           Often
# 1432                        0                           Often
#
#      mh_sharing_friends/fam_flag mh_bad_response_workplace  \
# 0                  Somewhat open                        No
# 1                  Somewhat open                        No
# 2                  Somewhat open            Maybe/Not sure
# 3                        Neutral                        No
# 4                  Somewhat open        Yes, I experienced
# ...                          ...                       ...
# 1428               Somewhat open            Maybe/Not sure
# 1429           Somewhat not open            Maybe/Not sure
# 1430               Somewhat open           Yes, I observed
# 1431               Somewhat open        Yes, I experienced
# 1432               Somewhat open            Maybe/Not sure
#
#      mh_discussion_cowork mh_eff_treat_impact_on_work  \
# 0                   Maybe        Not applicable to me
# 1                   Maybe                      Rarely
# 2                   Maybe        Not applicable to me
# 3                   Maybe                   Sometimes
# 4                   Maybe                   Sometimes
# ...                   ...                         ...
# 1428                Maybe        Not applicable to me
# 1429                Maybe                   Sometimes
# 1430                  Yes                      Rarely
# 1431                Maybe                   Sometimes
# 1432                Maybe        Not applicable to me
#
#                      mh_coverage_flag         sex   age
# 0     Not eligible for coverage / N/A        Male  39.0
# 1                                  No        Male  29.0
# 2                                  No        Male  38.0
# 3                                 Yes        Male  43.0
# 4                                 Yes      Female  43.0
# ...                               ...         ...   ...
# 1428                              Yes      Female  34.0
# 1429                              Yes        Male  56.0
# 1430                              Yes        Male  52.0
# 1431                     I don't know      Female  30.0
# 1432                              Yes  Non-binary  25.0
#
# [1433 rows x 12 columns]
